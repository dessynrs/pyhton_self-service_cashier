# %% [markdown]
# # **Hasil Test Case**

# %% [markdown]
# Test case pada file ini menunjukkan keseluruhan test case customer journey pada program Self-Service Cashier Register.

# %% [markdown]
# Tampilan awal program saat menjalankan program :
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Setekah menginput 1, maka tampilan akan berubah sbb.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Add to cart (menambahkan belanjaan ke keranjang)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Update nama pada keranjang (beras).
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Update qty pada keranjang (sabun mandi).
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Update harga pada keranjang (terigu 1 kg).
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Delete salah satu item.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pada fitur reset transaction, akan ada pertanyaan sebelum menghapus keseluruhan order. Jika tidak jadi, maka keranjang akan berisi produk yang sama.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fitur check order memungkinkan customer untuk melakukan pengecekan sebelum memutuskan akan check out atau melakukan perubahan order.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Jika customer tidak memilih 1, maka akan diarahkan ke menu awal. Customer dapat memilih fitur yang dibutuhkan untuk menambah order atau melakukan perubahan order.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Jika customer memilih 1 (ya), maka akan lanjut ke fitur check out. Hal yang sama jika customer langsung memilih fitu check out pada menu.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Jika customer memilih 0 (tidak delivery), maka proses rekap akhir untuk pembayaran dan program selesai.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Program secara otomatis akan mencatat pesanan customer pada database.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Jika customer memilih 1 (delivery), maka proses diarahkan ke penginputan detail pengiriman customer, yang secara otomatis akan masuk ke database customer delivery.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Tampilan database customer delivery sbb.
#
# ![image.png](data:image/png;base64,...)
